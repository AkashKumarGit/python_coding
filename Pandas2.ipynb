# %%
import pandas as pd
#SQL = Structured Query Language

# %%
users = pd.read_table('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user', 
                      sep='|', index_col='user_id')
users.head()
# Out:
#          age gender  occupation zip_code
# user_id
# 1         24      M  technician    85711
# 2         53      F       other    94043
# 3         23      M      writer    32067
# 4         24      M  technician    43537
# 5         33      F       other    15213

# %%
users.to_csv('/Users/akash/Downloads/users.csv')

# %%
users['age'].mean()
# Out:
# 34.05196182396607

# %%
users['occupation'].()
# Out:
#   File "<ipython-input-6-8360f87a6b55>", line 1
#     users['occupation'].()
#                         ^
# SyntaxError: invalid syntax

# %%
users.shape

# %%
users.info()

# %%
Ages = 23,25,27,28

Mean Age = (23+25+27+28)/4

# %%
25+27

# %%
52/2
# Out:
# 26.0

# %%
26/4
# Out:
# 6.5

# %%
users.head()
# Out:
#          age gender  occupation zip_code
# user_id
# 1         24      M  technician    85711
# 2         53      F       other    94043
# 3         23      M      writer    32067
# 4         24      M  technician    43537
# 5         33      F       other    15213

# %% [markdown]
# # Mean age per occupation

# %%
users.groupby('gender').age.mean()
# Out:
# gender
# F    33.813187
# M    34.149254
# Name: age, dtype: float64

# %% [markdown]
# # Male ratio per occupation and sort it from the most to the least

# %%
import numpy as np
'''
# create a function
def gender_to_numeric(x):
    if x == 'M':
        return 1
    if x == 'F':
        return 2

gender_to_numeric('M')
'''    
# apply the function to the gender column and create a new column
#users['gender_M'] = users['gender'].apply(gender_to_numeric)
users['gender_F'] = np.where(users['gender'] == 'F',1,0)
users['gender_M'] = np.where(users['gender'] == 'M',1,0)

# %%
users.head()
# Out:
#          age gender  occupation zip_code  gender_n  gender_F  gender_M
# user_id
# 1         24      M  technician    85711         1         0         1
# 2         53      F       other    94043         2         1         0
# 3         23      M      writer    32067         1         0         1
# 4         24      M  technician    43537         1         0         1
# 5         33      F       other    15213         2         1         0

# %%
users.loc[:,['gender','occupation','zip_code']]
# Out:
#         gender     occupation zip_code
# user_id
# 1            M     technician    85711
# 2            F          other    94043
# 3            M         writer    32067
# 4            M     technician    43537
# 5            F          other    15213
# ...        ...            ...      ...
# 939          F        student    33319
# 940          M  administrator    02215
# 941          M        student    97229
# 942          F      librarian    78209
# 943          M        student    77841
#
# [943 rows x 3 columns]

# %%
users['occupation'][10:15]
# Out:
# user_id
# 11        other
# 12        other
# 13     educator
# 14    scientist
# 15     educator
# Name: occupation, dtype: object

# %%
type(users['occupation'])
# Out:
# pandas.core.series.Series

# %%
type(users)
# Out:
# pandas.core.frame.DataFrame

# %%
type(1.4)

# %%
users.groupby('occupation').gender_F.sum()
# Out:
# occupation
# administrator    36
# artist           13
# doctor            0
# educator         26
# engineer          2
# entertainment     2
# executive         3
# healthcare       11
# homemaker         6
# lawyer            2
# librarian        29
# marketing        10
# none              4
# other            36
# programmer        6
# retired           1
# salesman          3
# scientist         3
# student          60
# technician        1
# writer           19
# Name: gender_F, dtype: int64

# %%
users.occupation.value_counts()
# Out:
# student          196
# other            105
# educator          95
# administrator     79
# engineer          67
# programmer        66
# librarian         51
# writer            45
# executive         32
# scientist         31
# artist            28
# technician        27
# marketing         26
# entertainment     18
# healthcare        16
# retired           14
# lawyer            12
# salesman          12
# none               9
# homemaker          7
# doctor             7
# Name: occupation, dtype: int64

# %%
136/196
# Out:
# 0.6938775510204082

# %%
a = users.groupby('occupation').gender_M.sum() / users.occupation.value_counts() * 100

# %%
a
# Out:
# administrator     54.430380
# artist            53.571429
# doctor           100.000000
# educator          72.631579
# engineer          97.014925
# entertainment     88.888889
# executive         90.625000
# healthcare        31.250000
# homemaker         14.285714
# lawyer            83.333333
# librarian         43.137255
# marketing         61.538462
# none              55.555556
# other             65.714286
# programmer        90.909091
# retired           92.857143
# salesman          75.000000
# scientist         90.322581
# student           69.387755
# technician        96.296296
# writer            57.777778
# dtype: float64

# %%
# sort to the most male 
a.sort_values(ascending=False)
# Out:
# doctor           100.000000
# engineer          97.014925
# technician        96.296296
# retired           92.857143
# programmer        90.909091
# executive         90.625000
# scientist         90.322581
# entertainment     88.888889
# lawyer            83.333333
# salesman          75.000000
# educator          72.631579
# student           69.387755
# other             65.714286
# marketing         61.538462
# writer            57.777778
# none              55.555556
# administrator     54.430380
# artist            53.571429
# librarian         43.137255
# healthcare        31.250000
# homemaker         14.285714
# dtype: float64

# %% [markdown]
# # For each occupation, calculate the minimum and maximum ages

# %%
users.groupby('occupation').age.agg(['min', 'max'])
# Out:
# occupation
# administrator    21
# artist           19
# doctor           28
# educator         23
# engineer         22
# entertainment    15
# executive        22
# healthcare       22
# homemaker        20
# lawyer           21
# librarian        23
# marketing        24
# none             11
# other            13
# programmer       20
# retired          51
# salesman         18
# scientist        23
# student           7
# technician       21
# writer           18
# Name: age, dtype: int64

# %% [markdown]
# # Combination of occupation and gender, calculate the mean age

# %%
users.groupby(['occupation', 'gender']).gender.count()
# Out:
# occupation     gender
# administrator  F          36
#                M          43
# artist         F          13
#                M          15
# doctor         M           7
# educator       F          26
#                M          69
# engineer       F           2
#                M          65
# entertainment  F           2
#                M          16
# executive      F           3
#                M          29
# healthcare     F          11
#                M           5
# homemaker      F           6
#                M           1
# lawyer         F           2
#                M          10
# librarian      F          29
#                M          22
# marketing      F          10
#                M          16
# none           F           4
#                M           5
# other          F          36
#                M          69
# programmer     F           6
#                M          60
# retired        F           1
#                M          13
# ...

# %% [markdown]
# # Percentage of women and men for each occupation

# %%
# create a data frame and apply count to gender
gender_ocup = users.groupby(['occupation', 'gender']).agg({'gender': 'count'})

# create a DataFrame and apply count for each occupation
occup_count = users.groupby(['occupation']).agg('count')

# divide the gender_ocup per the occup_count and multiply per 100
occup_gender = gender_ocup.div(occup_count, level = "occupation") * 100

occup_gender
# Out:
#                       age      gender  gender_F  gender_M  gender_n  zip_code
# occupation    gender
# administrator F       NaN   45.569620       NaN       NaN       NaN       NaN
#               M       NaN   54.430380       NaN       NaN       NaN       NaN
# artist        F       NaN   46.428571       NaN       NaN       NaN       NaN
#               M       NaN   53.571429       NaN       NaN       NaN       NaN
# doctor        M       NaN  100.000000       NaN       NaN       NaN       NaN
# educator      F       NaN   27.368421       NaN       NaN       NaN       NaN
#               M       NaN   72.631579       NaN       NaN       NaN       NaN
# engineer      F       NaN    2.985075       NaN       NaN       NaN       NaN
#               M       NaN   97.014925       NaN       NaN       NaN       NaN
# entertainment F       NaN   11.111111       NaN       NaN       NaN       NaN
#               M       NaN   88.888889       NaN       NaN       NaN       NaN
# ...

# %%
# present all rows from the 'gender column'
occup_gender.loc[: , 'gender']
# Out:
# occupation     gender
# administrator  F          45.569620
#                M          54.430380
# artist         F          46.428571
#                M          53.571429
# doctor         M         100.000000
# educator       F          27.368421
#                M          72.631579
# engineer       F           2.985075
#                M          97.014925
# entertainment  F          11.111111
#                M          88.888889
# executive      F           9.375000
#                M          90.625000
# healthcare     F          68.750000
#                M          31.250000
# homemaker      F          85.714286
#                M          14.285714
# lawyer         F          16.666667
#                M          83.333333
# librarian      F          56.862745
#                M          43.137255
# marketing      F          38.461538
#                M          61.538462
# none           F          44.444444
#                M          55.555556
# ...

# %%
raw_data_1 = {
        'subject_id': ['1', '2', '3', '4', '5'],
        'first_name': ['Alex', 'Amy', 'Allen', 'Alice', 'Ayoung'], 
        'last_name': ['Anderson', 'Ackerman', 'Ali', 'Aoni', 'Atiches']}

raw_data_2 = {
        'subject_id': ['4', '5', '6', '7', '8'],
        'first_name': ['Billy', 'Brian', 'Bran', 'Bryce', 'Betty'], 
        'last_name': ['Bonder', 'Black', 'Balwner', 'Brice', 'Btisan']}

raw_data_3 = {
        'subject_id': ['1', '2', '3', '4', '5', '7', '8', '9', '10', '11'],
        'test_id': [51, 15, 15, 61, 16, 14, 15, 1, 61, 16]}

# %%
type(raw_data_1)
# Out:
# dict

# %% [markdown]
# # Assign each to a variable called data1, data2, data3

# %%
data1 = pd.DataFrame(raw_data_1, columns = ['subject_id', 'first_name', 'last_name'])
data2 = pd.DataFrame(raw_data_2, columns = ['subject_id', 'first_name', 'last_name'])
data3 = pd.DataFrame(raw_data_3, columns = ['subject_id','test_id'])

data1
# Out:
#   subject_id first_name last_name
# 0          1       Alex  Anderson
# 1          2        Amy  Ackerman
# 2          3      Allen       Ali
# 3          4      Alice      Aoni
# 4          5     Ayoung   Atiches

# %%
data2
# Out:
#   subject_id first_name last_name
# 0          4      Billy    Bonder
# 1          5      Brian     Black
# 2          6       Bran   Balwner
# 3          7      Bryce     Brice
# 4          8      Betty    Btisan

# %% [markdown]
# # Joining the two dataframes along rows and assign all_data

# %%
all_data = pd.concat([data1, data2],axis=0)
all_data
# Out:
#   subject_id first_name last_name
# 0          1       Alex  Anderson
# 1          2        Amy  Ackerman
# 2          3      Allen       Ali
# 3          4      Alice      Aoni
# 4          5     Ayoung   Atiches
# 0          4      Billy    Bonder
# 1          5      Brian     Black
# 2          6       Bran   Balwner
# 3          7      Bryce     Brice
# 4          8      Betty    Btisan

# %% [markdown]
# # Joining the two dataframes along columns and assing to all_data_col

# %%
all_data_col = pd.concat([data1, data2], axis = 1)
all_data_col
# Out:
#   subject_id first_name last_name subject_id first_name last_name
# 0          1       Alex  Anderson          4      Billy    Bonder
# 1          2        Amy  Ackerman          5      Brian     Black
# 2          3      Allen       Ali          6       Bran   Balwner
# 3          4      Alice      Aoni          7      Bryce     Brice
# 4          5     Ayoung   Atiches          8      Betty    Btisan

# %%
data3
# Out:
#   subject_id  test_id
# 0          1       51
# 1          2       15
# 2          3       15
# 3          4       61
# 4          5       16
# 5          7       14
# 6          8       15
# 7          9        1
# 8         10       61
# 9         11       16

# %% [markdown]
# # Merge all_data and data3 along the subject_id value

# %%
pd.merge(data1, data3, on='subject_id',how=)
# Out:
#   File "<ipython-input-123-4ddc3184a0be>", line 1
#     pd.merge(data1, data3, on='subject_id',how=)
#                                                ^
# SyntaxError: invalid syntax

# %%
raw_data_1 = {
        'subject_id': ['1', '2', '3', '4', '5'],
        'first_name': ['Alex', 'Amy', 'Allen', 'Alice', 'Ayoung'], 
        'last_name': ['Anderson', 'Ackerman', 'Ali', 'Aoni', 'Atiches']}

raw_data_2 = {
        'subject_id': ['4', '5', '6', '7', '8'],
        'first_name1': ['Billy', 'Brian', 'Bran', 'Bryce', 'Betty'], 
        'last_name1': ['Bonder', 'Black', 'Balwner', 'Brice', 'Btisan']}

# %%
data1 = pd.DataFrame(raw_data_1, columns = ['subject_id', 'first_name', 'last_name'])
data2 = pd.DataFrame(raw_data_2, columns = ['subject_id', 'first_name1', 'last_name1'])

# %%
data1
# Out:
#   subject_id first_name last_name
# 0          1       Alex  Anderson
# 1          2        Amy  Ackerman
# 2          3      Allen       Ali
# 3          4      Alice      Aoni
# 4          5     Ayoung   Atiches

# %%
data2
# Out:
#   subject_id first_name1 last_name1
# 0          4       Billy     Bonder
# 1          5       Brian      Black
# 2          6        Bran    Balwner
# 3          7       Bryce      Brice
# 4          8       Betty     Btisan

# %% [markdown]
# # Merge only the data that has the same 'subject_id' on both data1 and data2

# %%
pd.merge(data1, data2, on='subject_id', how='inner')
# Out:
#   subject_id first_name last_name first_name1 last_name1
# 0          4      Alice      Aoni       Billy     Bonder
# 1          5     Ayoung   Atiches       Brian      Black

# %% [markdown]
# # Merge all values in data1 and data2, with matching records from both sides where available

# %%
pd.merge(data1, data2, on='subject_id',how='inner')
# Out:
#   subject_id first_name last_name first_name1 last_name1
# 0          4      Alice      Aoni       Billy     Bonder
# 1          5     Ayoung   Atiches       Brian      Black

# %%
data1
# Out:
#   subject_id first_name last_name
# 0          1       Alex  Anderson
# 1          2        Amy  Ackerman
# 2          3      Allen       Ali
# 3          4      Alice      Aoni
# 4          5     Ayoung   Atiches

# %%
data3
# Out:
#   subject_id  test_id
# 0          1       51
# 1          2       15
# 2          3       15
# 3          4       61
# 4          5       16
# 5          7       14
# 6          8       15
# 7          9        1
# 8         10       61
# 9         11       16

# %%
pd.merge(data1, data3, on='subject_id',how='inner')
# Out:
#   subject_id first_name last_name  test_id
# 0          1       Alex  Anderson       51
# 1          2        Amy  Ackerman       15
# 2          3      Allen       Ali       15
# 3          4      Alice      Aoni       61
# 4          5     Ayoung   Atiches       16
